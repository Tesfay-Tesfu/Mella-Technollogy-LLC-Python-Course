# %%
from IPython.display import Image
#:/BRAZIL_PhD/Fagundus/univap.jpg
Image(filename="/BRAZIL_PhD/Fagundus/univap.jpg")

# %% [markdown]
# # <span style='color:Blue'> Python Class by Prof. Valdir </span>

# %% [markdown]
# ### CORRECT QUESTIONS

# %% [markdown]
# # 12.
# Write a program to read a vector of 10 integer elements.
# Delete the 1st element of the vector by moving the subsequent elements one position to the beginning.
# Print the vector after removing the first element.

# %%
import numpy as np

vector_of_10 = np.arange(1,11)
vector_of_10 = vector_of_10[1:]
print(vector_of_10)
# Out:
# [ 2  3  4  5  6  7  8  9 10]

# %% [markdown]
# # 21,
# Equipment collects environmental temperature data.
# It organizes information as follows:
# a. The matrix td (7,24) stores the temperatures of the 7 days of the week,
# collecting 24 measurements in one day, carried out hourly)
# b. The tdm matrix (7) stores
# the daily average temperatures for the days of the week. w.
# c. The tmax (7) matrix stores the maximum temperatures of the days of the week

# %%
import numpy as np
td_value = np.random.rand(7, 24) * 30  
tdm_value = np.mean(td_value, axis=1)
tmax_value = np.max(td_value, axis=1)

# %%
print("Hourly data = ",td_value)
# Out:
# Hourly data =  [[14.51773348  7.31168931  4.06870934 18.95812645 25.28717569  7.98843543
#   17.2756381   9.32412878  1.73945404 23.43744509  0.04069566 18.28858836
#   22.32781405 21.7218854   2.48817391 14.21516869  1.96842132 16.50966717
#   11.47402894  9.00915884 25.1198264   7.9827774  19.44876957  4.8780842 ]
#  [ 6.31523646 29.30958948 27.10045718 11.99744348  7.18163031 16.40006441
#   21.78961455 27.705273   24.20715743  5.09915685 28.76140178 12.70399975
#    0.96849155 15.919816    4.30752035 13.04284858 18.99465738  8.22140402
#   15.16450668  7.00100384 11.77332487 21.16992008 22.36537061 27.60319015]
#  [ 1.34160192 28.98317089 17.78512241  6.54786281 12.07506379 19.31157778
#    1.64628933  0.57979822 16.91398976  7.70899339  5.1317428  12.34460224
#   23.29760074 12.50964958 25.56168997  8.05863793 11.99999465 25.62727893
#   27.58615499 21.73202194 22.15042035 22.01827068 23.44773447 22.14708483]
# ...

# %%
print("Daily data = ",tdm_value)
# Out:
# Daily data =  [12.72423315 16.04596162 15.68776477 15.57180178 15.53572736 17.30391996
#  14.77137033]

# %%
print("Maximum of each dayas = ",tmax_value)
# Out:
# Maximum of each dayas =  [25.28717569 29.30958948 28.98317089 28.56692889 27.55275259 29.26105773
#  29.62480161]

# %%
arq = open('avg.txt')
i = 0
for line in arq:
    print(line[:,-1])
arq.close

# %%
arq = open('avg.txt')
# arq.close
i = 0
for line in arq:
    if i == 10:
        print(line)
        else:
            i = i+1
arq.close

# %%
import matplolib pyplot as plt
arq = open('avg.txt')
L = []
for line in arq:
    L.append(int(line[:,-1]))
print(L)
plt.plot(L)
plt.show()
arq.close()

# %% [markdown]
# ##

# %%
arq2 = open("test.txt","w")
for x in range(Dadose.shape[0]):
    Linha = "

# %%
with open('serie1.txt', 'r') as file:
    data = [float(line.strip()) for line in file]
highest_value = max(data)

# Normalize
normalized_data = [value / highest_value for value in data]

# Rewrit the data
with open('series_normalized.txt', 'w') as file:
    for value in normalized_data:
        file.write(f"{value}\n")

print("Normalization completed. Data written to series1_norm.txt.")

# %%
# By: T.Y, Date 12/09/2023 or 1/1/2016 Geeze Calender, a gift of new year
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np

fig, ax = plt.subplots()
red = '#DA251D'
yellow = '#FFD100'

gezana = patches.Rectangle((0, 0), 2, 1, color=red)
ax.add_patch(gezana)

center_x = 1.3
center_y = 0.55  
radius_outer = 0.25  
radius_inner = 0.1  
angle = np.deg2rad(72)  

star_coords = []
for i in range(5):
    x_outer = center_x + radius_outer * np.cos(i * angle)
    y_outer = center_y + radius_outer * np.sin(i * angle)
    x_inner = center_x + radius_inner * np.cos((i + 0.5) * angle)
    y_inner = center_y + radius_inner * np.sin((i + 0.5) * angle)
    star_coords.extend([(x_outer, y_outer), (x_inner, y_inner)])

yellow_star = plt.Polygon(star_coords, closed=True, color=yellow)
ax.add_patch(yellow_star)

triangle_coords = [(0, 0), (0, 1), (0.96, 0.55)]

yellow_triangle = plt.Polygon(triangle_coords, closed=True, color=yellow)
ax.add_patch(yellow_triangle)

ax.set_xlim(0, 2)
ax.set_ylim(0, 1.5)
ax.axis('off')
plt.savefig("Gezana_Anbelbli.png")
plt.show()
