# %% [markdown]
# # Mella Math Operators using functions

# %% [markdown]
# # Functions in Python (def)
# # Definition: A function is a reusable block of code that performs a specific task.

# %% [markdown]
# <style>
#     body { font-family: 'Segoe UI', sans-serif; line-height: 1.6; color: #333; }
#     h1 { color: #2e8b57; text-align: center; }
#     h2 { color: #6a5acd; }
#     code { background: #f4f4f4; color: #d14; padding: 2px 5px; border-radius: 5px; }
#     pre { background: #2d2d2d; color: #f8f8f2; padding: 10px; border-radius: 8px; overflow-x: auto; }
#     ul { list-style-type: square; }
#     .note { background: #ffffcc; border-left: 6px solid #ffeb3b; padding: 10px; margin: 10px 0; }
# </style>
#
# <h1>✨ Python Functions (using <code>def</code>)</h1>
#
# <h2>🔧 What is a Function?</h2>
# <ul>
#     <li>A reusable block of code that performs a specific task.</li>
#     <li>Defined using the <code>def</code> keyword.</li>
#     <li>Improves code readability and avoids repetition.</li>
# </ul>
#
#
# <h2>🔤 Basic Syntax</h2>
# <pre><code>def function_name(parameters):
#     # code block
#     return result</code></pre>
#
# <h2>📌 Example</h2>
# <pre><code>def greet(name):
#     return f"Hello, {name}!"</code></pre>
#
# <div class="note">
#     <strong>Calling the function:</strong><br>
#     <code>greet("Aru")</code> returns <code>"Hello, Aru!"</code>
# </div>
#
# <h2>🧠 Types of Functions</h2>
# <ul>
#     <li><strong>Built-in:</strong> <code>print()</code>, <code>len()</code></li>
#     <li><strong>User-defined:</strong> Functions you create</li>
#     <li><strong>Lambda:</strong> Short anonymous functions</li>
# </ul>

# %%
# %%writefile Mella_Calculator.py
#############################
def add(x,y):# for Addition
  return x+y
#############################
def sub(x,y):# for Subtraction
  return x-y
##############################
def div(x,y):# for Division
  return x/y
##############################
def mult(x,y):# for Multiplication
  return x*y
# Out:
# Overwriting Mella_Calculator.py

# %%
from Mella_Calculator import add, mult,sub,div

# %%
add(23,45)
# Out:
# 68

# %%
mult(20,88)
# Out:
# 1760

# %%
# This is a question raised by Jay
def store_25():
    stored_values = []
    for i in range(90, 101):

        stored_values.append(i*0.25)
    return stored_values
my_values = store_25()
print(my_values)
# Out:
# [22.5, 22.75, 23.0, 23.25, 23.5, 23.75, 24.0, 24.25, 24.5, 24.75, 25.0]

# %%
# This is developed by Hailemichel
import pandas as pd
marks_dict = [
    {"Name": "Tesu", "Marks": 89},
    {"Name": "Juned", "Marks": 75},
    {"Name": "Kidus", "Marks": 80},
    {"Name": "Haile", "Marks": 99},
    {"Name": "Nanael", "Marks": 65}
]
Data_Marks = pd.DataFrame(marks_dict)
print(Data_Marks)


def grade(Mark):
    if mark >= 90:
        return "A"
    elif mark >= 80:
        return "B"
    elif mark >= 70:
        return "C"
    elif mark >= 60:
        return "D"
    else:
        return "F"
# Out:
#      Name  Marks
# 0    Tesu     89
# 1   Juned     75
# 2   Kidus     80
# 3   Haile     99
# 4  Nanael     65

# %%
#################################
"""
#    Dictioner ===> Dataframe ======> Analysing Dataframe using FUNCTION ##
"""
dict22 =  {"Name": ["Abebe", "BB", "CC","DD","EE", "FF", "GG","HH","II"],
           "Mark": [34,45, 65,50,55,66,77,88,98]}
print(dict22)
###############################################
import pandas as pd
df = pd.DataFrame(dict22)
print(df)
###############################################
def grading(df, column_name='Mark'):
    grades = []

    for mark in df[column_name]:
        if mark >= 90:
            grades.append("A")
        elif 85 <= mark < 90:
            grades.append("B")
        elif 65 <= mark < 80:
            grades.append("C")
        elif 55 <= mark < 65:
            grades.append("D")
        else:
            grades.append("F")

    df["Grade"] = grades
    return df
###############################################       <<<<<<<<<<<<===== Applying the function Pls take care the indention !!!
df = grading(df)
df
# Out:
# {'Name': ['Abebe', 'BB', 'CC', 'DD', 'EE', 'FF', 'GG', 'HH', 'II'], 'Mark': [34, 45, 65, 50, 55, 66, 77, 88, 98]}
#     Name  Mark
# 0  Abebe    34
# 1     BB    45
# 2     CC    65
# 3     DD    50
# 4     EE    55
# 5     FF    66
# 6     GG    77
# 7     HH    88
# 8     II    98
#     Name  Mark Grade
# 0  Abebe    34     F
# 1     BB    45     F
# 2     CC    65     C
# 3     DD    50     F
# 4     EE    55     D
# 5     FF    66     C
# 6     GG    77     C
# 7     HH    88     B
# 8     II    98     A

# %%
Simple_dictioner = {"Name": ["Abebe", "Abdu"],
                   "Age": [34, 25]}
print(Simple_dictioner)
# Out:
# {'Name': ['Abebe', 'Abdu'], 'Age': [34, 25]}

# %%
import pandas as pd
data = pd.DataFrame(Simple_dictioner)
print(data)

from * Table
# Out:
#     Name  Age
# 0  Abebe   34
# 1   Abdu   25

# %%
xx = int(input("Please enter the first deposit: "))
yy = int(input("Please enter the interest rate: "))
# Out:
# Please enter the first deposit:  5000
# Please enter the interest rate:  10

# %%
Total_deposit = xx + xx*yy/100
Total_deposit
# Out:
# 5500.0

# %%
"""
##### INDIVIDUAL ASSIGNMENT !!!!!

# 1, Please create an Interactive database
Hint: let's use simple interactive to write your name store it at the XX variable

Example:  
"""
XX = input("Please write your first Name: ")
# Out:
# Please write your first Name:  Tesfay

# %%
### You will see the interactive box looks like below !

# %% [markdown]
# ![image.png](attachment:03da913d-df62-429b-8a8c-d12b49a991c7.png)

# %%
print(XX)
# Out:
# Tesfay

# %%
n = int(input("How many rows you are looking for your Table/df? : " ))
names = []
age = []
for i in range(n):
    Names = input(f"Write The Name of  {i+1}st: "  )
    Age = int(input(f"Age of {i+1}: "))
    names.append(Names)
    age.append(Age)
df = pd.DataFrame({"Names": names,
                       "Ages": age
        
    })
    
df
# Out:
# How many rows you are looking for your Table/df? :  2
# Write The Name of  1:  ss
# Age of 1:  23
# Write The Name of  2:  dd
# Age of 2:  34
#   Names  Ages
# 0    ss    23
# 1    dd    34

# %%
import pandas as pd

n = int(input("How many rows do you want for your Table/df? : "))
names = []
ages = []

for i in range(n):
    name = input(f"Write the name of person {i+1}: ")
    age = int(input(f"Age of person {i+1}: "))
    names.append(name)
    ages.append(age)

df = pd.DataFrame({
    "Names": names,
    "Ages": ages
})

print(df)
# Out:
# How many rows do you want for your Table/df? :  3
# Write the name of person 1:  ww
# Age of person 1:  21
# Write the name of person 2:  ss
# Age of person 2:  32
# Write the name of person 3:  ee
# Age of person 3:  23
#   Names  Ages
# 0    ww    21
# 1    ss    32
# 2    ee    23

# %% [markdown]
# <h1 style="color: red; font-weight: bold;">WEEK TWO</h1>

# %% [markdown]
# <h3 style="color: red; font-weight: bold;">Please Download The orders_data.csv click on <a href="https://github.com/Tesfay-Tesfu/Mella-Technollogy-LLC-Python-Course/tree/main/Week_2" target="_blank">My-Github</a>
#  </h3>

# %% [markdown]
# ![image.png](attachment:932063d3-b341-4cab-aed0-680f6f48fd09.png)

# %% [markdown]
# # Reading/Importing Data from either our path OR from Tesfay-Tesfu, particularly at <a href="https://github.com/Tesfay-Tesfu/Mella-Technollogy-LLC-Python-Course/tree/main/Week_2" target="_blank">My-Github</a>

# %% [markdown]
# # PANDAS

# %% [markdown]
# <style>
#     body { font-family: 'Segoe UI', sans-serif; line-height: 1.6; color: #333; }
#     h1 { color: #1f77b4; text-align: center; }
#     h2 { color: #2ca02c; margin-top: 20px; }
#     ul { list-style-type: square; padding-left: 20px; }
#     code {
#         background: #f4f4f4;
#         color: #c7254e;
#         padding: 2px 6px;
#         border-radius: 5px;
#         font-size: 90%;
#     }
#     pre {
#         background-color: #2d2d2d;
#         color: #f8f8f2;
#         padding: 10px;
#         border-radius: 8px;
#         overflow-x: auto;
#     }
#     table {
#         width: 100%;
#         border-collapse: collapse;
#         margin-top: 15px;
#     }
#     th, td {
#         border: 1px solid #ccc;
#         padding: 6px 10px;
#         text-align: left;
#     }
#     th {
#         background-color: #f9f9f9;
#     }
# </style>
#
# <h1>🐼 Pandas - Python Data Analysis Library</h1>
#
# <h2>📌 What is Pandas?</h2>
# <ul>
#     <li>A powerful open-source library for <strong>data analysis</strong> and <strong>manipulation</strong>.</li>
#     <li>Built on top of <code>NumPy</code>.</li>
#     <li>Great for working with structured data (tables, CSV, Excel, SQL, etc.).</li>
# </ul>
#
# <h2>✅ Core Data Structures:</h2>
# <ul>
#     <li><strong>Series</strong>: 1D labeled array (like a single column).</li>
#     <li><strong>DataFrame</strong>: 2D table (like an Excel sheet).</li>
# </ul>
#
# <h2>🧪 Common Operations:</h2>
# <pre><code>import pandas as pd
#
# df = pd.read_csv("data.csv")     # Load data
# df.head()                        # Show first rows
# df["Age"].mean()                 # Average of 'Age'
# df[df["Score"] > 90]             # Filter rows
# df["Grade"] = "A"                # Add new column</code></pre>
#
# <h2>🔧 Useful Methods:</h2>
# <table>
#     <tr><th>Method</th><th>Description</th></tr>
#     <tr><td><code>read_csv()</code></td><td>Load data from CSV file</td></tr>
#     <tr><td><code>head()</code></td><td>Show top rows of the DataFrame</td></tr>
#     <tr><td><code>drop()</code></td><td>Remove rows or columns</td></tr>
#     <tr><td><code>fillna()</code></td><td>Fill missing values</td></tr>
#     <tr><td><code>groupby()</code></td><td>Group and summarize data</td></tr>
#     <tr><td><code>merge()</code></td><td>Join two datasets</td></tr>
#     <tr><td><code>to_csv()</code></td><td>Export DataFrame to CSV</td></tr>
# </table>

# %% [markdown]
# # IMPORTING and READINGS using PANDAS

# %% [markdown]
# <style>
#     body { font-family: 'Segoe UI', sans-serif; line-height: 1.6; color: #333; }
#     h1, h2 { color: #1f77b4; }
#     h1 { text-align: center; }
#     ul { padding-left: 20px; }
#     code {
#         background: #f4f4f4;
#         color: #c7254e;
#         padding: 2px 6px;
#         border-radius: 5px;
#         font-size: 95%;
#     }
#     pre {
#         background-color: #2d2d2d;
#         color: #f8f8f2;
#         padding: 10px;
#         border-radius: 6px;
#         overflow-x: auto;
#     }
#     table {
#         width: 100%;
#         border-collapse: collapse;
#         margin-top: 15px;
#     }
#     th, td {
#         border: 1px solid #ddd;
#         padding: 8px 12px;
#     }
#     th {
#         background-color: #f2f2f2;
#         color: #333;
#     }
# </style>
#
# <h1>📚 Pandas - Reading Data from Various Sources</h1>
#
# <h2>🧾 1. CSV Files</h2>
# <pre><code>df = pd.read_csv("data.csv")</code></pre>
# <p>Use <code>sep='\\t'</code> for tab-separated files (TSV).</p>
#
# <h2>📘 2. Excel Files (.xlsx, .xls)</h2>
# <pre><code>df = pd.read_excel("data.xlsx", sheet_name="Sheet1")</code></pre>
# <p>Requires <code>openpyxl</code> or <code>xlrd</code> installed.</p>
#
# <h2>📄 3. Text Files (.txt)</h2>
# <pre><code>df = pd.read_table("data.txt", sep="\\t")</code></pre>
#
# <h2>📊 4. Stata Files (.dta)</h2>
# <pre><code>df = pd.read_stata("data.dta")</code></pre>
#
# <h2>📦 5. JSON Files</h2>
# <pre><code>df = pd.read_json("data.json")</code></pre>
#
# <h2>🖼️ 6. Image Files (PNG, JPG)</h2>
# <p>Pandas doesn't directly handle images, but you can use:</p>
# <pre><code>from PIL import Image
# import numpy as np
#
# img = Image.open("image.png")
# img_array = np.array(img)
# df = pd.DataFrame(img_array)</code></pre>
#
# <h2>🗃️ 7. SQL Databases</h2>
# <pre><code>import sqlite3
# conn = sqlite3.connect("my_db.db")
# df = pd.read_sql("SELECT * FROM my_table", conn)</code></pre>
#
# <h2>📑 8. Other Formats</h2>
# <table>
#     <tr><th>Format</th><th>Pandas Function</th></tr>
#     <tr><td>Parquet</td><td><code>pd.read_parquet()</code></td></tr>
#     <tr><td>Feather</td><td><code>pd.read_feather()</code></td></tr>
#     <tr><td>HDF5</td><td><code>pd.read_hdf()</code></td></tr>
#     <tr><td>Clipboard</td><td><code>pd.read_clipboard()</code></td></tr>
# </table>

# %%
import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt

# %%
# path = "/Please_Use_Your_Path_here/orders_data.csv"
#  OR 
path = r"C:\Aru_New_Future\Mella-Technollogy-LLC-Python-Course-main\Mella-Technollogy-LLC-Python-Course-main\Backups\Week_2\orders_data.csv"

# %%
df = pd.read_csv(path)

# %%
df.tail(3)
# Out:
#       Order Id  Order Date       Ship Mode   Segment        Country  \
# 9991      9992  07-08-2022  Standard Class  Consumer  United States
# 9992      9993  19-11-2022  Standard Class  Consumer  United States
# 9993      9994  17-07-2022    Second Class  Consumer  United States
#
#              City       State  Postal Code Region         Category  \
# 9991   Costa Mesa  California        92627   West       Technology
# 9992   Costa Mesa  California        92627   West  Office Supplies
# 9993  Westminster  California        92683   West  Office Supplies
#
#      Sub Category       Product Id  cost price  List Price  Quantity  \
# 9991       Phones  TEC-PH-10003645         220         260         2
# 9992        Paper  OFF-PA-10004041          30          30         4
# 9993   Appliances  OFF-AP-10002684         210         240         2
#
#       Discount Percent
# 9991                 2
# 9992                 3
# 9993                 3

# %% [markdown]
# <h2 style="color: red; font-weight: bold;">#. We can Keep Copy of our "df" as df_copy</h2>

# %%
df_copy = df.copy() ## TO PREVENT CONAMINATION OUR 1st Dataframe/Table

# %%
df_copy
# Out:
#       Order Id  Order Date       Ship Mode    Segment        Country  \
# 0            1  01-03-2023    Second Class   Consumer  United States
# 1            2  15-08-2023    Second Class   Consumer  United States
# 2            3  10-01-2023    Second Class  Corporate  United States
# 3            4  18-06-2022  Standard Class   Consumer  United States
# 4            5  13-07-2022  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  18-02-2023    Second Class   Consumer  United States
# 9990      9991  17-03-2023  Standard Class   Consumer  United States
# 9991      9992  07-08-2022  Standard Class   Consumer  United States
# 9992      9993  19-11-2022  Standard Class   Consumer  United States
# 9993      9994  17-07-2022    Second Class   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# ...

# %%
df_copy.head() # Head is to print few top rows, tail is to print few last rows
# Out:
#    Order Id  Order Date       Ship Mode    Segment        Country  \
# 0         1  01-03-2023    Second Class   Consumer  United States
# 1         2  15-08-2023    Second Class   Consumer  United States
# 2         3  10-01-2023    Second Class  Corporate  United States
# 3         4  18-06-2022  Standard Class   Consumer  United States
# 4         5  13-07-2022  Standard Class   Consumer  United States
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub Category       Product Id  cost price  List Price  Quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %% [markdown]
# <h1 style= "color:red; font-weight:bold;"># Print the column Names</h1>

# %%
df.columns # To observe the intended column Names
# Out:
# Index(['Order Id', 'Order Date', 'Ship Mode', 'Segment', 'Country', 'City',
#        'State', 'Postal Code', 'Region', 'Category', 'Sub Category',
#        'Product Id', 'cost price', 'List Price', 'Quantity',
#        'Discount Percent'],
#       dtype='object')

# %% [markdown]
# <h1 style="color:red; font-weight: bold;">#. df.head(n) and df.tail(n)

# %%
df.head()
df.tail()
# Out:
#       Order Id  Order Date       Ship Mode   Segment        Country  \
# 9989      9990  18-02-2023    Second Class  Consumer  United States
# 9990      9991  17-03-2023  Standard Class  Consumer  United States
# 9991      9992  07-08-2022  Standard Class  Consumer  United States
# 9992      9993  19-11-2022  Standard Class  Consumer  United States
# 9993      9994  17-07-2022    Second Class  Consumer  United States
#
#              City       State  Postal Code Region         Category  \
# 9989        Miami     Florida        33180  South        Furniture
# 9990   Costa Mesa  California        92627   West        Furniture
# 9991   Costa Mesa  California        92627   West       Technology
# 9992   Costa Mesa  California        92627   West  Office Supplies
# 9993  Westminster  California        92683   West  Office Supplies
#
#      Sub Category       Product Id  cost price  List Price  Quantity  \
# 9989  Furnishings  FUR-FU-10001889          30          30         3
# ...

# %% [markdown]
# <h1 style="color: red; font-weight: bold;">1. Shape of Data</h1>

# %%
df.shape # To know the matrix of our structured data
# Out:
# (9994, 16)

# %% [markdown]
# <h2 style="color: red; font-weight: bold;">1.1. Check Data Type Information</h2>

# %%
df.info() # Crucial to determine our datatypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order Id          9994 non-null   int64
#  1   Order Date        9994 non-null   object
#  2   Ship Mode         9993 non-null   object
#  3   Segment           9994 non-null   object
#  4   Country           9994 non-null   object
#  5   City              9994 non-null   object
#  6   State             9994 non-null   object
#  7   Postal Code       9994 non-null   int64
#  8   Region            9994 non-null   object
#  9   Category          9994 non-null   object
#  10  Sub Category      9994 non-null   object
#  11  Product Id        9994 non-null   object
#  12  cost price        9994 non-null   int64
#  13  List Price        9994 non-null   int64
#  14  Quantity          9994 non-null   int64
#  15  Discount Percent  9994 non-null   int64
# dtypes: int64(6), object(10)
# ...

# %% [markdown]
# <h2 style="color: red; font-weight: bold;">2. Length of Data</h2>

# %%
len(df) # length is an optional way of shape that useful to know our data lenght
# Out:
# 9994

# %% [markdown]
# <h2 style="color: red; font-weight: bold;">3. Unique Values </h2>

# %%
df['Region'].unique()# Used to know how many unique values, or specific objects are at the particular column throught the entire rows
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %% [markdown]
# <h2 style="color: red; font-weight: bold;">4. Rename Selected Column/s</h2>

# %%
# Rename are coming to the picture when we need to rewrite a proper naming of columns or to shorten the column names
df = df.rename(columns = {"Order Id": "ID", "Postal Code": "Post"}).head(2)
df
# Out:
#    ID  Order Date     Ship Mode   Segment        Country       City     State  \
# 0   1  01-03-2023  Second Class  Consumer  United States  Henderson  Kentucky
# 1   2  15-08-2023  Second Class  Consumer  United States  Henderson  Kentucky
#
#     Post Region   Category Sub Category       Product Id  cost price  \
# 0  42420  South  Furniture    Bookcases  FUR-BO-10001798         240
# 1  42420  South  Furniture       Chairs  FUR-CH-10000454         600
#
#    List Price  Quantity  Discount Percent
# 0         260         2                 2
# 1         730         3                 3

# %% [markdown]
# <h2 style="color: red; font-weight: bold;">5. Drop Selected Column/s</h2>

# %%
df = df.drop(columns = ["Ship Mode", "Post"]).head(2) # Imagine your company has given you 1000 columns data and your project may ...
# only target on 20 columns, then you should drop the 980 columns. This command help data analyst to save their energy, memory, running time...
df
# Out:
#    ID  Order Date   Segment        Country       City     State Region  \
# 0   1  01-03-2023  Consumer  United States  Henderson  Kentucky  South
# 1   2  15-08-2023  Consumer  United States  Henderson  Kentucky  South
#
#     Category Sub Category       Product Id  cost price  List Price  Quantity  \
# 0  Furniture    Bookcases  FUR-BO-10001798         240         260         2
# 1  Furniture       Chairs  FUR-CH-10000454         600         730         3
#
#    Discount Percent
# 0                 2
# 1                 3

# %% [markdown]
# <h2 style="color: red; font-weight: bold;">6. Insert New Calculated Columns</h2>

# %%
df["Qt_Price"] = df["List Price"]*df["Quantity"] # Calculated new columns are our daily job when we are working as data analyst
df
# Out:
#    ID  Order Date   Segment        Country       City     State Region  \
# 0   1  01-03-2023  Consumer  United States  Henderson  Kentucky  South
# 1   2  15-08-2023  Consumer  United States  Henderson  Kentucky  South
#
#     Category Sub Category       Product Id  cost price  List Price  Quantity  \
# 0  Furniture    Bookcases  FUR-BO-10001798         240         260         2
# 1  Furniture       Chairs  FUR-CH-10000454         600         730         3
#
#    Discount Percent  Qt_Price
# 0                 2       520
# 1                 3      2190

# %% [markdown]
# <h1 style="color: red; font-weight: bold;">7. Formating Time/Datetime &</h1>
# <h3 style="color: green; font-weight: bold;"># Extracting:  DD, MM, YYYY</h3>

# %%
df['Order Date'].info() # In python/Pandas data formating especially time formating is mandatory to make understandable for our tool
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2 entries, 0 to 1
# Series name: Order Date
# Non-Null Count  Dtype
# --------------  -----
# 2 non-null      object
# dtypes: object(1)
# memory usage: 148.0+ bytes

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], format = '%d-%m-%Y')
df['Order Date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2 entries, 0 to 1
# Series name: Order Date
# Non-Null Count  Dtype
# --------------  -----
# 2 non-null      datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 148.0 bytes

# %% [markdown]
# <h2 style="color: red; font-weight: bold;">8. Find Total NaN Values</h2>

# %%
df.isna().sum() # NaNs are like a weed in data, but people are used it differently
# Some of the data analyst may collect the NaNs and burn them out, some of the data analyst again taking care of the weeds and interpret it
# Burning is EASY, so let's focuse on how to TREAT them haha....
# Out:
# ID                  0
# Order Date          0
# Segment             0
# Country             0
# City                0
# State               0
# Region              0
# Category            0
# Sub Category        0
# Product Id          0
# cost price          0
# List Price          0
# Quantity            0
# Discount Percent    0
# Qt_Price            0
# dtype: int64

# %% [markdown]
# <h2 style="color: red; font-weight: bold;">9. Filling NaN values</h2>

# %%
df.fillna(0) # Refer the fun at number 8

# %%
df["Targeted_column"] = df["Targeted_column"].interpolate(method = 'bfill') # OR fillna instead of interpolate
df["Targeted_column"] = df["Targeted_column"].interpolate(method = 'ffill') # OR fillna instead of interpolate

# %%
df
# Out:
#    ID Order Date   Segment        Country       City     State Region  \
# 0   1 2023-03-01  Consumer  United States  Henderson  Kentucky  South
# 1   2 2023-08-15  Consumer  United States  Henderson  Kentucky  South
#
#     Category Sub Category       Product Id  cost price  List Price  Quantity  \
# 0  Furniture    Bookcases  FUR-BO-10001798         240         260         2
# 1  Furniture       Chairs  FUR-CH-10000454         600         730         3
#
#    Discount Percent  Qt_Price
# 0                 2       520
# 1                 3      2190

# %% [markdown]
# <h2 style="color: red; font-weight: bold;">10. Extract Targeted Value</h2>

# %%
new_small_table = df_copy[df_copy['Product Id']== 'FUR-CH-10000454'] # Extract using target value is important to extract some unique and relevant information.
# Out:
#       Order Id  Order Date       Ship Mode      Segment        Country  \
# 1            2  15-08-2023    Second Class     Consumer  United States
# 149        150  23-01-2022  Standard Class    Corporate  United States
# 4022      4023  01-05-2022  Standard Class     Consumer  United States
# 4734      4735  26-11-2022  Standard Class    Corporate  United States
# 4850      4851  01-01-2023  Standard Class     Consumer  United States
# 4880      4881  24-06-2022    Second Class    Corporate  United States
# 5141      5142  15-04-2022  Standard Class     Consumer  United States
# 5468      5469  27-03-2022     First Class  Home Office  United States
# 6113      6114  09-12-2023  Standard Class     Consumer  United States
# 7389      7390  30-03-2023  Standard Class     Consumer  United States
#
#                City         State  Postal Code   Region   Category  \
# 1         Henderson      Kentucky        42420    South  Furniture
# ...

# %% [markdown]
# <h2 style="color: red; font-weight: bold;">11. Extract Selected Rows Based On thresholds</h2>

# %%
Thresholding_table = df[(df['Quantity'] > 5) & (df['Quantity'] <= 8)] # Boolean is a very crucial ...
#    to create multiple new analyzed tables that may needed to submite to the decision makers
Thresholding_table
# Out:
#       Order Id  Order Date       Ship Mode      Segment        Country  \
# 5            6  13-03-2022   Not Available     Consumer  United States
# 7            8  25-01-2022  Standard Class     Consumer  United States
# 16          17  04-02-2022  Standard Class     Consumer  United States
# 21          22  16-07-2023  Standard Class    Corporate  United States
# 22          23  06-05-2023  Standard Class    Corporate  United States
# ...        ...         ...             ...          ...            ...
# 9966      9967  21-02-2022    Second Class    Corporate  United States
# 9969      9970  18-11-2023  Standard Class     Consumer  United States
# 9974      9975  17-11-2022  Standard Class  Home Office  United States
# 9977      9978  03-12-2023  Standard Class  Home Office  United States
# 9982      9983  27-05-2023  Standard Class     Consumer  United States
#
#               City       State  Postal Code   Region         Category  \
# ...

# %% [markdown]
# <h2 style="color: red; font-weight: bold;">12. Agregation based on Selected column</h2>

# %%
df['Quantity'].sum()
# Out:
# np.int64(37873)

# %%
df['Quantity'].mean()
# Out:
# np.float64(3.789573744246548)

# %%
df.describe()
# Out:
#           Order Id   Postal Code    cost price    List Price     Quantity  \
# count  9994.000000   9994.000000   9994.000000   9994.000000  9994.000000
# mean   4997.500000  55190.379428    201.189714    229.756854     3.789574
# std    2885.163629  32063.693350    537.743203    623.245839     2.225110
# min       1.000000   1040.000000      0.000000      0.000000     1.000000
# 25%    2499.250000  23223.000000     20.000000     20.000000     2.000000
# 50%    4997.500000  56430.500000     50.000000     50.000000     3.000000
# 75%    7495.750000  90008.000000    180.000000    210.000000     5.000000
# max    9994.000000  99301.000000  18110.000000  22640.000000    14.000000
#
#        Discount Percent
# count       9994.000000
# mean           3.484090
# std            1.114211
# min            2.000000
# 25%            2.000000
# 50%            3.000000
# 75%            4.000000
# max            5.000000

# %% [markdown]
# <h2 style="color: red; font-weight: bold;">13. Sort Data Ascending/Descending</h2>

# %%
df.sort_values(by = "List Price", ascending = True, inplace = True)
df
# Out:
#       Order Id  Order Date       Ship Mode      Segment        Country  \
# 5199      5200  08-07-2023  Standard Class     Consumer  United States
# 5206      5207  26-07-2023  Standard Class     Consumer  United States
# 9187      9188  31-08-2022  Standard Class  Home Office  United States
# 655        656  06-01-2022  Standard Class     Consumer  United States
# 658        659  01-07-2022        Same Day  Home Office  United States
# ...        ...         ...             ...          ...            ...
# 4190      4191  29-11-2022  Standard Class     Consumer  United States
# 2623      2624  11-04-2023     First Class  Home Office  United States
# 8153      8154  25-10-2022     First Class     Consumer  United States
# 6826      6827  14-08-2022  Standard Class    Corporate  United States
# 2697      2698  13-10-2023  Standard Class  Home Office  United States
#
#                City         State  Postal Code   Region         Category  \
# ...
