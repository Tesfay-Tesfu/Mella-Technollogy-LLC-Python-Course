# %% [markdown]
# # Data Cleaning

# %%
import numpy as np
import pandas as pd

# %%
path1 = r'C:\Aru_New_Future\Data_Cleaning\Mella_Data_Cleaning\Data_to_be_clean\data1.csv'

# %%
df1 = pd.read_csv(path1)
df1
# Out:
#    Unnamed: 0                 State  TotalPop Hispanic   White   Black Native  \
# 0           0              Colorado   5278906   20.78%  69.90%   3.55%  0.57%
# 1           1           Connecticut   3593222   15.60%  67.68%  10.35%  0.13%
# 2           2              Delaware    926454    8.82%  64.63%  20.74%  0.26%
# 3           3  District of Columbia    647484    9.17%  33.10%  51.78%  0.20%
# 4           4               Florida  19645772   21.34%  59.08%  15.17%  0.21%
# 5           5               Georgia  10006693    8.42%  54.29%  32.09%  0.19%
#
#    Asian Pacific       Income           GenderPop
# 0  2.66%     NaN  $64,657.80    2648667M_2630239F
# 1  4.02%   0.02%  $76,146.56    1751607M_1841615F
# 2  3.27%     NaN  $61,827.98      448413M_478041F
# 3  3.38%   0.03%  $75,466.36      306674M_340810F
# 4  2.28%   0.05%  $50,690.19   9600009M_10045763F
# 5  3.10%   0.05%  $50,811.08    4883331M_5123362F

# %%
path2 = r'C:\Aru_New_Future\Data_Cleaning\Mella_Data_Cleaning\Data_to_be_clean\data2.csv'
df2 = pd.read_csv(path2)
df2
# Out:
#    Unnamed: 0     State  TotalPop Hispanic   White   Black Native   Asian  \
# 0           0   Georgia  10006693    8.42%  54.29%  32.09%  0.19%   3.10%
# 1           1    Hawaii   1406299    9.19%  25.03%   2.05%  0.14%  36.59%
# 2           2     Idaho   1616547   11.51%  83.14%   0.57%  1.47%   1.14%
# 3           3  Illinois  12873761   15.60%  60.86%  17.11%  0.12%   4.48%
# 4           4   Indiana   6568645    6.54%  78.43%  11.19%  0.19%   1.58%
# 5           5      Iowa   3093526    5.30%  87.72%   3.26%  0.29%   1.70%
#
#   Pacific       Income          GenderPop
# 0   0.05%  $50,811.08   4883331M_5123362F
# 1   8.76%  $73,264.43     709871M_696428F
# 2   0.13%  $48,017.32     810464M_806083F
# 3   0.02%  $59,587.05   6316899M_6556862F
# 4   0.03%  $48,616.23   3235263M_3333382F
# 5   0.06%  $53,017.75   1534595M_1558931F

# %%
path3 = r'C:\Aru_New_Future\Data_Cleaning\Mella_Data_Cleaning\Data_to_be_clean\data1.csv'
df3 = pd.read_csv(path3)
df3
# Out:
#    Unnamed: 0                 State  TotalPop Hispanic   White   Black Native  \
# 0           0              Colorado   5278906   20.78%  69.90%   3.55%  0.57%
# 1           1           Connecticut   3593222   15.60%  67.68%  10.35%  0.13%
# 2           2              Delaware    926454    8.82%  64.63%  20.74%  0.26%
# 3           3  District of Columbia    647484    9.17%  33.10%  51.78%  0.20%
# 4           4               Florida  19645772   21.34%  59.08%  15.17%  0.21%
# 5           5               Georgia  10006693    8.42%  54.29%  32.09%  0.19%
#
#    Asian Pacific       Income           GenderPop
# 0  2.66%     NaN  $64,657.80    2648667M_2630239F
# 1  4.02%   0.02%  $76,146.56    1751607M_1841615F
# 2  3.27%     NaN  $61,827.98      448413M_478041F
# 3  3.38%   0.03%  $75,466.36      306674M_340810F
# 4  2.28%   0.05%  $50,690.19   9600009M_10045763F
# 5  3.10%   0.05%  $50,811.08    4883331M_5123362F

# %%
path4 = r'C:\Aru_New_Future\Data_Cleaning\Mella_Data_Cleaning\Data_to_be_clean\data1.csv'
df4 = pd.read_csv(path4)
df4
# Out:
#    Unnamed: 0                 State  TotalPop Hispanic   White   Black Native  \
# 0           0              Colorado   5278906   20.78%  69.90%   3.55%  0.57%
# 1           1           Connecticut   3593222   15.60%  67.68%  10.35%  0.13%
# 2           2              Delaware    926454    8.82%  64.63%  20.74%  0.26%
# 3           3  District of Columbia    647484    9.17%  33.10%  51.78%  0.20%
# 4           4               Florida  19645772   21.34%  59.08%  15.17%  0.21%
# 5           5               Georgia  10006693    8.42%  54.29%  32.09%  0.19%
#
#    Asian Pacific       Income           GenderPop
# 0  2.66%     NaN  $64,657.80    2648667M_2630239F
# 1  4.02%   0.02%  $76,146.56    1751607M_1841615F
# 2  3.27%     NaN  $61,827.98      448413M_478041F
# 3  3.38%   0.03%  $75,466.36      306674M_340810F
# 4  2.28%   0.05%  $50,690.19   9600009M_10045763F
# 5  3.10%   0.05%  $50,811.08    4883331M_5123362F

# %%
import os
import pandas as pd
###############################################################################
folder = "Data_to_be_clean"
table_list = []
###############################################################################
for filename in os.listdir(folder):
    if filename.startswith("data") and filename.endswith(".csv"):
        filepath = os.path.join(folder, filename)
        data = pd.read_csv(filepath)
        table_list.append(data)
###############################################################################
if table_list:
    Tables = pd.concat(table_list).reset_index(drop=True)
else:
    print("No CSV files found.")
Tables
# Out:
#     Unnamed: 0                 State  TotalPop Hispanic   White   Black  \
# 0            0              Colorado   5278906   20.78%  69.90%   3.55%
# 1            1           Connecticut   3593222   15.60%  67.68%  10.35%
# 2            2              Delaware    926454    8.82%  64.63%  20.74%
# 3            3  District of Columbia    647484    9.17%  33.10%  51.78%
# 4            4               Florida  19645772   21.34%  59.08%  15.17%
# 5            5               Georgia  10006693    8.42%  54.29%  32.09%
# 6            0               Georgia  10006693    8.42%  54.29%  32.09%
# 7            1                Hawaii   1406299    9.19%  25.03%   2.05%
# 8            2                 Idaho   1616547   11.51%  83.14%   0.57%
# 9            3              Illinois  12873761   15.60%  60.86%  17.11%
# 10           4               Indiana   6568645    6.54%  78.43%  11.19%
# 11           5                  Iowa   3093526    5.30%  87.72%   3.26%
# ...

# %%
Tables
# Out:
#     index  Unnamed: 0                 State  TotalPop Hispanic   White  \
# 0       0           0              Colorado   5278906   20.78%  69.90%
# 1       1           1           Connecticut   3593222   15.60%  67.68%
# 2       2           2              Delaware    926454    8.82%  64.63%
# 3       3           3  District of Columbia    647484    9.17%  33.10%
# 4       4           4               Florida  19645772   21.34%  59.08%
# 5       5           5               Georgia  10006693    8.42%  54.29%
# 6       0           0               Georgia  10006693    8.42%  54.29%
# 7       1           1                Hawaii   1406299    9.19%  25.03%
# 8       2           2                 Idaho   1616547   11.51%  83.14%
# 9       3           3              Illinois  12873761   15.60%  60.86%
# 10      4           4               Indiana   6568645    6.54%  78.43%
# 11      5           5                  Iowa   3093526    5.30%  87.72%
# ...

# %%
Tables.columns
# Out:
# Index(['index', 'Unnamed: 0', 'State', 'TotalPop', 'Hispanic', 'White',
#        'Black', 'Native', 'Asian', 'Pacific', 'Income', 'GenderPop'],
#       dtype='object')

# %%
Tables.shape
# Out:
# (24, 11)

# %%
len(Tables)
# Out:
# 24

# %%
Tables.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  24 non-null     int64
#  1   State       24 non-null     object
#  2   TotalPop    24 non-null     int64
#  3   Hispanic    24 non-null     object
#  4   White       24 non-null     object
#  5   Black       24 non-null     object
#  6   Native      24 non-null     object
#  7   Asian       24 non-null     object
#  8   Pacific     21 non-null     object
#  9   Income      24 non-null     object
#  10  GenderPop   24 non-null     object
# dtypes: int64(2), object(9)
# memory usage: 2.2+ KB

# %%
Tables.isnull().sum()
# Out:
# Unnamed: 0    0
# State         0
# TotalPop      0
# Hispanic      0
# White         0
# Black         0
# Native        0
# Asian         0
# Pacific       3
# Income        0
# GenderPop     0
# dtype: int64

# %%
Tables.duplicated().value_counts()
# Out:
# False    24
# Name: count, dtype: int64

# %% [markdown]
# # Handle Duplicate Data

# %%
Tables_copy.duplicated().value_counts()

# %%
Tables_copy = Tables_copy.drop_duplicates()
Tables_copy.shape

# %% [markdown]
# ## Cleaning the Dataset

# %%
Tables_copy = Tables.copy()

# %% [markdown]
# ### 1. Remove unused variable

# %%
Tables_copy = Tables_copy.drop(columns = ['Unnamed: 0'], axis=1)
Tables_copy.head(3)
# Out:
#          State  TotalPop Hispanic   White   Black Native  Asian Pacific  \
# 0     Colorado   5278906   20.78%  69.90%   3.55%  0.57%  2.66%     NaN
# 1  Connecticut   3593222   15.60%  67.68%  10.35%  0.13%  4.02%   0.02%
# 2     Delaware    926454    8.82%  64.63%  20.74%  0.26%  3.27%     NaN
#
#         Income          GenderPop
# 0  $64,657.80   2648667M_2630239F
# 1  $76,146.56   1751607M_1841615F
# 2  $61,827.98     448413M_478041F

# %%
Tables_copy.head(2)
# Out:
#          State  TotalPop Hispanic   White   Black Native  Asian Pacific  \
# 0     Colorado   5278906   20.78%  69.90%   3.55%  0.57%  2.66%     NaN
# 1  Connecticut   3593222   15.60%  67.68%  10.35%  0.13%  4.02%   0.02%
#
#         Income          GenderPop
# 0  $64,657.80   2648667M_2630239F
# 1  $76,146.56   1751607M_1841615F

# %%
Tables_copy.Income = Tables_copy.Income.replace('[,\$]', '', regex=True)
Tables_copy.Income = pd.to_numeric(Tables_copy.Income)
Tables_copy
# Out:
#                    State  TotalPop Hispanic   White   Black Native   Asian  \
# 0               Colorado   5278906   20.78%  69.90%   3.55%  0.57%   2.66%
# 1            Connecticut   3593222   15.60%  67.68%  10.35%  0.13%   4.02%
# 2               Delaware    926454    8.82%  64.63%  20.74%  0.26%   3.27%
# 3   District of Columbia    647484    9.17%  33.10%  51.78%  0.20%   3.38%
# 4                Florida  19645772   21.34%  59.08%  15.17%  0.21%   2.28%
# 5                Georgia  10006693    8.42%  54.29%  32.09%  0.19%   3.10%
# 6                Georgia  10006693    8.42%  54.29%  32.09%  0.19%   3.10%
# 7                 Hawaii   1406299    9.19%  25.03%   2.05%  0.14%  36.59%
# 8                  Idaho   1616547   11.51%  83.14%   0.57%  1.47%   1.14%
# 9               Illinois  12873761   15.60%  60.86%  17.11%  0.12%   4.48%
# 10               Indiana   6568645    6.54%  78.43%  11.19%  0.19%   1.58%
# ...

# %%
race_column = ['Hispanic', 'White', 'Black', 'Native', 'Asian', 'Pacific']
for col in race_column:
    Tables_copy[col] = Tables_copy[col].replace('[,\%]', '', regex=True)
    Tables_copy[col] = pd.to_numeric(Tables_copy[col])
Tables_copy.head(3)
# Out:
#          State  TotalPop  Hispanic  White  Black  Native  Asian  Pacific  \
# 0     Colorado   5278906     20.78  69.90   3.55    0.57   2.66      NaN
# 1  Connecticut   3593222     15.60  67.68  10.35    0.13   4.02     0.02
# 2     Delaware    926454      8.82  64.63  20.74    0.26   3.27      NaN
#
#      Income          GenderPop
# 0  64657.80  2648667M_2630239F
# 1  76146.56  1751607M_1841615F
# 2  61827.98    448413M_478041F

# %%
print(Tables_copy.dtypes)
# Out:
# State         object
# TotalPop       int64
# Hispanic     float64
# White        float64
# Black        float64
# Native       float64
# Asian        float64
# Pacific      float64
# Income       float64
# GenderPop     object
# dtype: object

# %% [markdown]
# # Split Major column into Small Columns

# %%
gender_split = Tables_copy['GenderPop'].str.split("_")
Tables_copy['MalePop'] = gender_split.str.get(0)
Tables_copy['FemalePop'] = gender_split.str.get(1)
Tables_copy.head(3)
# Out:
#      State  TotalPop  Hispanic  White  Black  Native  Asian  Pacific  \
# 0  Alabama   4830620      3.75  61.88  31.25    0.45   1.05     0.03
# 1   Alaska    733375      5.91  60.91   2.85   16.39   5.45     1.06
# 2  Arizona   6641928     29.57  57.12   3.85    4.36   2.88     0.17
#
#      Income          GenderPop   MalePop FemalePop
# 0  43296.36  2341093M_2489527F  2341093M  2489527F
# 1  70354.74    384160M_349215F   384160M   349215F
# 2  54207.82  3299088M_3342840F  3299088M  3342840F

# %%
Tables_copy.MalePop = Tables_copy.MalePop.str[0:-1]
Tables_copy.FemalePop = Tables_copy.FemalePop.str[0:-1]
#######################################################
Tables_copy.MalePop = pd.to_numeric(Tables_copy.MalePop)
Tables_copy.FemalePop = pd.to_numeric(Tables_copy.FemalePop)

# %%
Tables_copy = Tables_copy.drop('GenderPop', axis=1)
Tables_copy.head(3)
# Out:
#      State  TotalPop  Hispanic  White  Black  Native  Asian  Pacific  \
# 0  Alabama   4830620      3.75  61.88  31.25    0.45   1.05     0.03
# 1   Alaska    733375      5.91  60.91   2.85   16.39   5.45     1.06
# 2  Arizona   6641928     29.57  57.12   3.85    4.36   2.88     0.17
#
#      Income  MalePop  FemalePop
# 0  43296.36  2341093  2489527.0
# 1  70354.74   384160   349215.0
# 2  54207.82  3299088  3342840.0

# %%
Tables_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   State      60 non-null     object
#  1   TotalPop   60 non-null     int64
#  2   Hispanic   60 non-null     float64
#  3   White      60 non-null     float64
#  4   Black      60 non-null     float64
#  5   Native     60 non-null     float64
#  6   Asian      60 non-null     float64
#  7   Pacific    55 non-null     float64
#  8   Income     60 non-null     float64
#  9   MalePop    60 non-null     int64
#  10  FemalePop  57 non-null     float64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 5.3+ KB

# %%
Tables_copy.Pacific = Tables_copy.Pacific.fillna(Tables_copy.Pacific.mean())

# %%
Tables_copy.FemalePop = Tables_copy.FemalePop.fillna(Tables_copy.TotalPop - Tables_copy.MalePop)

# %%
Tables_copy.isnull().sum()
# Out:
# State        0
# TotalPop     0
# Hispanic     0
# White        0
# Black        0
# Native       0
# Asian        0
# Pacific      0
# Income       0
# MalePop      0
# FemalePop    0
# dtype: int64

# %%
print('Before dataset is cleaned: \n')
print(Tables.dtypes)
Tables.head()
# Out:
# Before dataset is cleaned:
#
# index          int64
# Unnamed: 0     int64
# State         object
# TotalPop       int64
# Hispanic      object
# White         object
# Black         object
# Native        object
# Asian         object
# Pacific       object
# Income        object
# GenderPop     object
# dtype: object
#    index  Unnamed: 0       State  TotalPop Hispanic   White   Black  Native  \
# 0      0           0     Alabama   4830620    3.75%  61.88%  31.25%   0.45%
# 1      1           1      Alaska    733375    5.91%  60.91%   2.85%  16.39%
# 2      2           2     Arizona   6641928   29.57%  57.12%   3.85%   4.36%
# 3      3           3    Arkansas   2958208    6.22%  71.14%  18.97%   0.52%
# 4      4           4  California  38421464   37.29%  40.22%   5.68%   0.41%
#
#     Asian Pacific       Income            GenderPop
# 0   1.05%   0.03%  $43,296.36     2341093M_2489527F
# 1   5.45%   1.06%  $70,354.74       384160M_349215F
# ...

# %%
print('After dataset is cleaned: \n')
print(Tables_copy.dtypes)
Tables_copy.head()
# Out:
# After dataset is cleaned:
#
# State         object
# TotalPop       int64
# Hispanic     float64
# White        float64
# Black        float64
# Native       float64
# Asian        float64
# Pacific      float64
# Income       float64
# MalePop        int64
# FemalePop    float64
# dtype: object
#         State  TotalPop  Hispanic  White  Black  Native  Asian  Pacific  \
# 0     Alabama   4830620      3.75  61.88  31.25    0.45   1.05     0.03
# 1      Alaska    733375      5.91  60.91   2.85   16.39   5.45     1.06
# 2     Arizona   6641928     29.57  57.12   3.85    4.36   2.88     0.17
# 3    Arkansas   2958208      6.22  71.14  18.97    0.52   1.14     0.15
# 4  California  38421464     37.29  40.22   5.68    0.41  13.05     0.35
#
#      Income   MalePop   FemalePop
# 0  43296.36   2341093   2489527.0
# 1  70354.74    384160    349215.0
# 2  54207.82   3299088   3342840.0
# 3  41935.63   1451913   1506295.0
# 4  67264.78  19087135  19334329.0

# %%
Tables_copy.to_csv('YourPath/cleaned_data.csv', header=True)

# %%
Tables_copy[Tables_copy['Hispanic'] >= 90]
# Out:
#           State  TotalPop  Hispanic  White  Black  Native  Asian  Pacific  \
# 46  Puerto Rico   3583073     98.89   0.77   0.09     0.0   0.08      0.0
#
#       Income  MalePop  FemalePop
# 46  20720.54  1713860  1869213.0
